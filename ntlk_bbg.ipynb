# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from tika import parser

raw = parser.from_file('Daughter of Destiny.pdf')
raw = str(raw)
safe_text = raw.encode('utf-8', errors='ignore')
safe_text = str(safe_text).replace("\n", "").replace("\\", "")
print('--- safe text ---' )
#print( safe_text )


#print(raw['content'])
# Out:
# 2019-04-26 03:30:02,555 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2019-04-26 03:30:07,599 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# --- safe text ---

# %%
import re

# %%
from urllib.request import urlopen
url = "https://www.gutenberg.org/files/58606/58606-0.txt"
raw = urlopen(url).read()
txt = raw.decode('utf-8')
import re

# %%
def clean_text(text):

    # remove HTML tags
    #text = re.sub(r'<.*?>', '', text)
    
    # remove the characters [\], ['] and ["]
    #text = re.sub(r"\\", "", text)    
    #text = re.sub(r"\'", "", text)    
    #text = re.sub(r"\"", "", text) 
    text = re.sub(r"\d", "", text) #This is to remove any digit from the text. 
    #text = re.sub(r"•\xa0", "", text) #This can be used to remove any text.
   # text = re.sub(r"\ufeff", "", text)
    #text = re.sub(r"\w","", text, flags = re.I) this is to remove all the word characters. The addition "flags = re.I" refers to case sensitive whether small or capital letters.
    #text = re.sub(r"\W", "", text, flags=re.I) The capital W function is used to remove all non-word characters. It removes also spaces as well.  
    #text = re.sub(r"[,@\'?\.$%_]", "", text, flags=re.I) #The square bracket [] solves this problem. 
    
    
    # convert text to lowercase
    text = text.strip().lower()
    #.strip() with no arguments (or None as the first argument) removes all whitespace at the start and end, including spaces, tabs, newlines and carriage returns
    
    # replace punctuation characters with spaces
    # 
    filters='!"\'#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n \r'
    translate_dict = dict((c, " ") for c in filters)
    translate_map = str.maketrans(translate_dict)
    text = text.translate(translate_map)

    return text

# %%
text1 = clean_text(safe_text)
#text1

# %%
tokens = nltk.word_tokenize(text1)
tokens
# Out:
# ['b',
#  'status',
#  'content',
#  'nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnmicrosoft',
#  'word',
#  'daughter',
#  'of',
#  'destiny',
#  'docnnn',
#  'nnnndaughter',
#  'of',
#  'destiny',
#  'copyright',
#  'xcxa',
#  'www',
#  'bhutto',
#  'org',
#  'nnbenazir',
#  'nnbhutto',
#  'nnan',
#  'nnautobiography',
#  'nn',
#  'nn',
#  'nn',
#  'nndaughter',
#  'nnof',
#  'n',
#  'nndestiny',
#  'n',
#  'nn',
#  'nnnndaughter',
#  'of',
#  'destiny',
#  'copyright',
#  'xcxa',
#  'www',
#  'bhutto',
#  'org',
#  'nn',
#  'nn',
#  'nnpreface',
#  'nn',
#  'nn',
#  'nn',
#  'nn',
#  'nni',
#  'have',
#  'always',
#  'believed',
#  'in',
#  'the',
#  'importance',
#  'of',
#  'historic',
#  'record',
#  'when',
#  'the',
#  'ngovernment',
#  'of',
#  'my',
#  'father',
#  'zulfikar',
#  'ali',
#  'bhutto',
#  'was',
#  'overthrown',
#  'in',
#  'i',
#  'nencouraged',
#  'many',
#  'of',
#  'those',
#  'who',
#  'had',
#  'worked',
#  'closely',
#  'with',
#  'him',
#  'to',
#  'write',
#  'about',
#  'the',
#  'nbhutto',
#  'period',
#  'but',
#  'in',
#  'the',
#  'difficult',
#  'years',
#  'of',
#  'martial',
#  'law',
#  'that',
#  'followed',
#  'in',
#  'pakistan',
#  'nmany',
#  'from',
#  'my',
#  'father',
#  's',
#  'government',
#  'were',
#  'busy',
#  'fighting',
#  'the',
#  'persecution',
#  'and',
#  'the',
#  'nfalse',
#  'cases',
#  'brought',
#  'against',
#  'them',
#  'by',
#  'the',
#  'military',
#  'regime',
#  'others',
#  'had',
#  'fled',
#  'into',
#  'nexile',
#  'and',
#  'had',
#  'no',
#  'access',
#  'to',
#  'their',
#  'personal',
#  'papers',
#  'my',
#  'own',
#  'involvement',
#  'in',
#  'the',
#  'nstruggle',
#  'to',
#  'return',
#  'democracy',
#  'to',
#  'pakistan',
#  'and',
#  'the',
#  'years',
#  'i',
#  'consequently',
#  'spent',
#  'nimprisoned',
#  'without',
#  'charge',
#  'made',
#  'it',
#  'impossible',
#  'for',
#  'me',
#  'to',
#  'write',
#  'a',
#  'book',
#  'on',
#  'my',
#  'nfather',
#  's',
#  'government',
#  'myself',
#  'n',
#  'n',
#  'more',
#  'than',
#  'a',
#  'million',
#  'of',
#  'my',
#  'countrymen',
#  'came',
#  'out',
#  'to',
#  'greet',
#  'me',
#  'when',
#  'i',
#  'nreturned',
#  'to',
#  'pakistan',
#  'from',
#  'two',
#  'years',
#  'of',
#  'exile',
#  'in',
#  'april',
#  'catapulting',
#  'me',
#  'into',
#  'the',
#  'nglare',
#  'of',
#  'international',
#  'publicity',
#  'suddenly',
#  'i',
#  'received',
#  'several',
#  'offers',
#  'to',
#  'write',
#  'not',
#  'my',
#  'nfather',
#  's',
#  'story',
#  'but',
#  'my',
#  'own',
#  'i',
#  'hesitated',
#  'it',
#  'was',
#  'one',
#  'matter',
#  'to',
#  'write',
#  'about',
#  'my',
#  'father',
#  'nwho',
#  'had',
#  'become',
#  'the',
#  'democratically',
#  'elected',
#  'prime',
#  'minister',
#  'of',
#  'pakistan',
#  'and',
#  'had',
#  'nlasting',
#  'achievements',
#  'to',
#  'his',
#  'name',
#  'and',
#  'quite',
#  'another',
#  'to',
#  'write',
#  'about',
#  'myself',
#  'nwhose',
#  'most',
#  'important',
#  'political',
#  'battles',
#  'were',
#  'still',
#  'to',
#  'be',
#  'fought',
#  'it',
#  'seemed',
#  'npresumptuous',
#  'i',
#  'thought',
#  'autobiographies',
#  'were',
#  'written',
#  'in',
#  'the',
#  'autumn',
#  'of',
#  'one',
#  's',
#  'life',
#  'nlooking',
#  'back',
#  'n',
#  'n',
#  'a',
#  'friend',
#  's',
#  'chance',
#  'remark',
#  'changed',
#  'my',
#  'mind',
#  'what',
#  'is',
#  'not',
#  'recorded',
#  'is',
#  'not',
#  'nremembered',
#  'she',
#  'told',
#  'me',
#  'i',
#  'saw',
#  'her',
#  'point',
#  'like',
#  'many',
#  'in',
#  'pakistan',
#  'i',
#  'had',
#  'nexperienced',
#  'the',
#  'dark',
#  'years',
#  'of',
#  'martial',
#  'law',
#  'unlike',
#  'many',
#  'i',
#  'had',
#  'the',
#  'opportunity',
#  'to',
#  'nput',
#  'those',
#  'experiences',
#  'on',
#  'record',
#  'it',
#  'is',
#  'important',
#  'that',
#  'the',
#  'world',
#  'remember',
#  'the',
#  'nrepression',
#  'we',
#  'in',
#  'pakistan',
#  'had',
#  'to',
#  'bear',
#  'following',
#  'general',
#  'zia',
#  's',
#  'coup',
#  'd',
#  'etat',
#  'n',
#  'nn',
#  'writing',
#  'the',
#  'book',
#  'has',
#  'been',
#  'difficult',
#  'it',
#  'has',
#  'meant',
#  'reliving',
#  'the',
#  'pain',
#  'of',
#  'the',
#  'npast',
#  'but',
#  'it',
#  'has',
#  'also',
#  'been',
#  'cathartic',
#  'forcing',
#  'me',
#  'for',
#  'the',
#  'first',
#  'time',
#  'to',
#  'come',
#  'to',
#  'terms',
#  'nwith',
#  'memories',
#  'i',
#  'had',
#  'been',
#  'trying',
#  'to',
#  'escape',
#  'n',
#  'nn',
#  'this',
#  'is',
#  'my',
#  'story',
#  'events',
#  'as',
#  'i',
#  'saw',
#  'them',
#  'felt',
#  'them',
#  'reacted',
#  'to',
#  'them',
#  'it',
#  'is',
#  'not',
#  'nan',
#  'in',
#  'depth',
#  'study',
#  'of',
#  'pakistan',
#  'but',
#  'a',
#  'glance',
#  'into',
#  'the',
#  'transformation',
#  'of',
#  'a',
#  'society',
#  'nfrom',
#  'democracy',
#  'to',
#  'dictatorship',
#  'let',
#  'it',
#  'also',
#  'be',
#  'a',
#  'call',
#  'for',
#  'freedom',
#  'nn',
#  'nbenazir',
#  'bhutto',
#  'nnjune',
#  'nkarachi',
#  'pakistan',
#  'nnnndaughter',
#  'of',
#  'destiny',
#  'copyright',
#  'xcxa',
#  'www',
#  'bhutto',
#  'org',
#  'nn',
#  'n',
#  'nnapril',
#  'nn',
#  'n',
#  'nn',
#  'nn',
#  'nnnndaughter',
#  'of',
#  'destiny',
#  'copyright',
#  'xcxa',
#  'www',
#  'bhutto',
#  'org',
#  'nn',
#  'nn',
#  'nnthe',
#  'assassixefxbfxbdatioxefxbfxbd',
#  'nnof',
#  'my',
#  'father',
#  'nn',
#  'nn',
#  'nnthey',
#  'killed',
#  'my',
#  'father',
#  'in',
#  'the',
#  'early',
#  'morning',
#  'hours',
#  'of',
#  'april',
#  'inside',
#  'nrawalpindi',
#  'district',
#  'jail',
#  'imprisoned',
#  'with',
#  'my',
#  'mother',
#  'a',
#  'few',
#  'miles',
#  'away',
#  'in',
#  'a',
#  'ndeserted',
#  'police',
#  'training',
#  'camp',
#  'at',
#  'sihala',
#  'i',
#  'felt',
#  'the',
#  'moment',
#  'of',
#  'my',
#  'father',
#  's',
#  'death',
#  'ndespite',
#  'the',
#  'valiums',
#  'my',
#  'mother',
#  'had',
#  'given',
#  'me',
#  'to',
#  'try',
#  'to',
#  'get',
#  'through',
#  'the',
#  'agonizing',
#  'nnight',
#  'i',
#  'suddenly',
#  'sat',
#  'bolt',
#  'upright',
#  'in',
#  'bed',
#  'at',
#  'a',
#  'm',
#  'no',
#  '!',
#  'the',
#  'scream',
#  'burst',
#  'through',
#  'nthe',
#  'knots',
#  'in',
#  'my',
#  'throat',
#  'no',
#  '!',
#  'i',
#  'couldn',
#  't',
#  'breathe',
#  'didn',
#  't',
#  'want',
#  'to',
#  'breathe',
#  'papa',
#  '!',
#  'npapa',
#  '!',
#  'i',
#  'felt',
#  'cold',
#  'so',
#  'cold',
#  'in',
#  'spite',
#  'of',
#  'the',
#  'heat',
#  'and',
#  'couldn',
#  't',
#  'stop',
#  'shaking',
#  'there',
#  'nwas',
#  'nothing',
#  'my',
#  'mother',
#  'and',
#  'i',
#  'could',
#  'say',
#  'to',
#  'console',
#  'each',
#  'other',
#  'somehow',
#  'the',
#  'nhours',
#  'passed',
#  'as',
#  'we',
#  'huddled',
#  'together',
#  'in',
#  'the',
#  'bare',
#  'police',
#  'quarters',
#  'we',
#  'were',
#  'ready',
#  'nat',
#  'dawn',
#  'to',
#  'accompany',
#  'my',
#  'father',
#  's',
#  'body',
#  'to',
#  'our',
#  'ancestral',
#  'family',
#  'graveyard',
#  'nn',
#  'n',
#  'i',
#  'am',
#  'in',
#  'iddat',
#  'and',
#  'can',
#  't',
#  'receive',
#  'outsiders',
#  'you',
#  'talk',
#  'to',
#  'him',
#  'my',
#  'mother',
#  'said',
#  'nndully',
#  'when',
#  'the',
#  'jailer',
#  'arrived',
#  'as',
#  'she',
#  'began',
#  'a',
#  'widow',
#  's',
#  'four',
#  'months',
#  'and',
#  'ten',
#  'days',
#  'of',
#  'nseclusion',
#  'from',
#  'strangers',
#  'n',
#  'ni',
#  'walked',
#  'into',
#  'the',
#  'cracked',
#  'cement',
#  'floored',
#  'front',
#  'room',
#  'that',
#  'was',
#  'supposed',
#  'to',
#  'nnserve',
#  'as',
#  'our',
#  'sitting',
#  'room',
#  'it',
#  'stank',
#  'of',
#  'mildew',
#  'and',
#  'rot',
#  'n',
#  'n',
#  'we',
#  'are',
#  'ready',
#  'to',
#  'leave',
#  'with',
#  'the',
#  'prime',
#  'minister',
#  'i',
#  'told',
#  'the',
#  'junior',
#  'jailor',
#  'standing',
#  'nnnervously',
#  'before',
#  'me',
#  'n',
#  'n',
#  'they',
#  'have',
#  'already',
#  'taken',
#  'him',
#  'to',
#  'be',
#  'buried',
#  'he',
#  'said',
#  'nn',
#  'n',
#  'i',
#  'felt',
#  'as',
#  'if',
#  'he',
#  'had',
#  'struck',
#  'me',
#  'without',
#  'his',
#  'family',
#  'i',
#  'asked',
#  'bitterly',
#  'even',
#  'nthe',
#  'criminals',
#  'in',
#  'the',
#  'military',
#  'regime',
#  'know',
#  'that',
#  'it',
#  'is',
#  'our',
#  'family',
#  's',
#  'religious',
#  'obligation',
#  'nto',
#  'accompany',
#  'his',
#  'body',
#  'to',
#  'recite',
#  'the',
#  'prayers',
#  'for',
#  'the',
#  'dead',
#  'to',
#  'see',
#  'his',
#  'face',
#  'before',
#  'nburial',
#  'we',
#  'applied',
#  'to',
#  'the',
#  'jail',
#  'superintendent',
#  'n',
#  'nn',
#  'they',
#  'have',
#  'taken',
#  'him',
#  'he',
#  'interrupted',
#  'nnnndaughter',
#  'of',
#  'destiny',
#  'copyright',
#  'xcxa',
#  'www',
#  'bhutto',
#  'org',
#  'nn',
#  'n',
#  'taken',
#  'him',
#  'where',
#  'the',
#  'jailer',
#  'was',
#  'silent',
#  'n',
#  'nn',
#  'it',
#  'was',
#  'very',
#  'peaceful',
#  'he',
#  'finally',
#  'replied',
#  'i',
#  'have',
#  'brought',
#  'what',
#  'was',
#  'left',
#  'n',
#  'n',
#  'he',
#  'handed',
#  'me',
#  'the',
#  'pitiful',
#  'items',
#  'from',
#  'my',
#  'father',
#  's',
#  'death',
#  'cell',
#  'one',
#  'by',
#  'one',
#  'my',
#  'nfather',
#  's',
#  'shalwar',
#  'khameez',
#  'the',
#  'long',
#  'shirt',
#  'and',
#  'loose',
#  'trousers',
#  'he',
#  'd',
#  'worn',
#  'to',
#  'the',
#  'end',
#  'nrefusing',
#  'as',
#  'a',
#  'political',
#  'prisoner',
#  'to',
#  'wear',
#  'the',
#  'uniform',
#  'of',
#  'a',
#  'condemned',
#  'criminal',
#  'the',
#  'ntiffin',
#  'box',
#  'for',
#  'food',
#  'that',
#  'for',
#  'the',
#  'last',
#  'ten',
#  'days',
#  'he',
#  'had',
#  'refused',
#  'the',
#  'roll',
#  'of',
#  'bedding',
#  'nthey',
#  'had',
#  'allowed',
#  'him',
#  'only',
#  'after',
#  'the',
#  'broken',
#  'wires',
#  'of',
#  'his',
#  'cot',
#  'had',
#  'lacerated',
#  'his',
#  'nback',
#  'his',
#  'drinking',
#  'cup',
#  'n',
#  'nn',
#  'where',
#  'is',
#  'his',
#  'ring',
#  'i',
#  'managed',
#  'to',
#  'ask',
#  'the',
#  'jailer',
#  'n',
#  'n',
#  'did',
#  'he',
#  'have',
#  'a',
#  'ring',
#  'he',
#  'asked',
#  'n',
#  'nn',
#  'i',
#  'watched',
#  'him',
#  'make',
#  'a',
#  'great',
#  'show',
#  'of',
#  'fishing',
#  'through',
#  'his',
#  'bag',
#  'through',
#  'his',
#  'npockets',
#  'finally',
#  'he',
#  'handed',
#  'me',
#  'my',
#  'father',
#  's',
#  'ring',
#  'which',
#  'toward',
#  'the',
#  'end',
#  'had',
#  'nregularly',
#  'slipped',
#  'off',
#  'his',
#  'emaciated',
#  'fingers',
#  'n',
#  'nn',
#  'peaceful',
#  'it',
#  'was',
#  'very',
#  'peaceful',
#  'he',
#  'kept',
#  'muttering',
#  'how',
#  'could',
#  'a',
#  'hanging',
#  'nbe',
#  'peaceful',
#  'n',
#  'nn',
#  'basheer',
#  'and',
#  'ibrahim',
#  'our',
#  'family',
#  'bearers',
#  'who',
#  'brought',
#  'us',
#  'supplies',
#  'every',
#  'nday',
#  'because',
#  'the',
#  'authorities',
#  'did',
#  'not',
#  'provide',
#  'us',
#  'with',
#  'food',
#  'came',
#  'into',
#  'the',
#  'room',
#  'nbasheer',
#  's',
#  'face',
#  'went',
#  ...]

# %% [markdown]
# # complete list of tags

# %% [markdown]
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
#sentence = """At eight o'clock on Thursday morning
#... Arthur didn't feel very good."""
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f66459ed0677> in <module>()
#       1 #sentence = """At eight o'clock on Thursday morning
#       2 #... Arthur didn't feel very good."""
# ----> 3 tokens = nltk.word_tokenize(sentence)
#       4 tokens
#
# NameError: name 'sentence' is not defined

# %%
tagged = nltk.pos_tag(tokens)

# %%
#tagged = nltk.pos_tag(text1)
#full book

# %%
tagged[0:6]
# Out:
# [('b', 'NN'),
#  ('status', 'NN'),
#  ('content', 'NN'),
#  ('nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnmicrosoft', 'RB'),
#  ('word', 'NN'),
#  ('daughter', 'NN')]

# %%
tagged
type(tagged)
# Out:
# list

# %%
y=list()
for word, tag in tagged:
    if tag  in ['UH']:
        y.append(word)

# %%
len(text1)
# Out:
# 933361

# %%
len(y)
# Out:
# 10

# %%
len(tokens)
# Out:
# 166833

# %%
print(y)
# Out:
# ['yes', 'yes', 'oh', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']

# %%
set(y)
# Out:
# {'oh', 'yes'}

# %%
from textblob import TextBlob

# %%
#type(file['col1'])
yt=list()
for line in y:
    tb=TextBlob(line).sentiment
    yt.extend(tb)

# %%
n=yt.count(0)

# %%
summ=0
for i in range(n):
    summ=summ+yt[i]

# %%
print(summ)
# Out:
# 4658.254979464966

# %%
# finding ! in the text directly, interjections from bb sahiba book
bbg_text=clean_text(safe_text)
import re
x=re.findall('[a-zA-Z]+\!+',bbg_text)
print(x)
# Out:
# ['no!', 'no!', 'papa!', 'npapa!', 'allah!', 'allah!', 'sahib!', 'him!', 'bhutto!', 'bhutto!', 'go!', 'me!', 'quickly!', 'through!', 'yasmin!', 'tonight!', 'npapa!', 'out!', 'out!', 'you!', 'alive!', 'murderers!', 'hurry!', 'hurry!', 'us!', 'revenge!', 'revenge!', 'boycott!', 'boycott!', 'look!', 'look!', 'zindabad!', 'zindabad!', 'bhutto!', 'up!', 'others!', 'rights!', 'down!', 'bhutto!', 'look!', 'stop!', 'no!', 'war!', 'war!', 'pilots!', 'on!', 'president!', 'rumors!', 'him!', 'india!', 'hai!', 'nhai!', 'born!', 'born!', 'ouch!', 'luck!', 'hilia!', 'over!', 'gone!', 'up!', 'dressed!', 'hurry!', 'over!', 'nnover!', 'him!', 'quickly!', 'hide!', 'pinkie!', 'sunny!', 'hurry!', 'leaving!', 'papa!', 'treason!', 'bhutto!', 'bhutto!', 't!', 't!', 'quiet!', 'backs!', 'behind!', 'him!', 'bhutto!', 'bhutto!', 'man!', 'bhutto!', 'karo!', 'karo!', 'bhutto!', 'lord!', 'overruled!', 'objection!', 'down!', 'not!', 'her!', 'scene!', 'case!', 'won!', 'won!', 'conditioner!', 'mummy!', 'gas!', 'gas!', 'shoulder!', 'mummy!', 'mummy!', 'bang!', 'bang!', 'public!', 'bhutto!', 'nbhutto!', 'murderers!', 'murderers!', 'papa!', 'smiling!', 'searched!', 'enough!', 'will!', 'father!', 'father!', 'birthday!', 'rasha!', 'welcome!', 'dogs!', 'yasmin!', 'yasmin!', 'yasmin!', 'tonight!', 'amina!', 'tonight!', 'tonight!', 'her!', 'clifton!', 'house!', 'mummy!', 'mummy!', 'here!', 'me!', 'them!', 'them!', 'away!', 'you!', 'whisper!', 'no!', 'no!', 'oh!', 'hush!', 'nothing!', 'that!', 'me!', 'allah!', 'laila!', 'nashilli!', 'terrorists!', 'murderers!', 'assassins!', 'dictator!', 'what!', 'nzindabad!', 'bhutto!', 'nnxexxcmummy!', 'pinkie!', 'day!', 'nmir!', 'coat!', 'vote!', 'crime!', 'ncrash!', 'surprise!', 'no!', 'me!', 'out!', 'out!', 'flat!', 'quickly!', 'nnquickly!', 'no!', 'no!', 'ambulance!', 'resuscitated!', 'gogi!', 'oxygen!', 'heart!', 'no!', 'try!', 'try!', 'akbar!', 'great!', 'stop!', 'e!', 'me!', 'me!', 'nnsamiya!', 'amina!', 'abbasi!', 'jeevay!', 'live!', 'yes!', 'no!', 'yes!', 'jahve!', 'go!', 'jahve!', 'jahve!', 'jahve!', 'days!', 'benazir!', 'nbenazir!', 'za!', 'za!', 'za!', 'benazir!', 'bhutto!', 'benazir!', 'duck!', 'duck!', 'police!', 'way!', 'nway!', 'read!', 'bhutto!', 'bhutto!', 'nsentences!', 'dead!', 'dead!', 'dead!', 'baby!', 'cards!', 'benazir!', 'nbenazir!', 'benazir!', 'benazir!', 'zero!']

# %%
len(x)
# Out:
# 232

# %%
from tika import parser

raw = parser.from_file('If-I-am-assassinated-by-Shaheed-Bhutto.pdf')
raw = str(raw)
Bhutto1_text = raw.encode('utf-8', errors='ignore')
Bhutto1_text = str(Bhutto1_text).replace("\n", "").replace("\\", "")
print('--- safe text ---' )
#print( Bhutto1_text )
# Out:
# --- safe text ---

# %%
def clean_text(text):

     
    text = re.sub(r"\d", "", text) #This is to remove any digit from the text. 
    
    
    # convert text to lowercase
    text = text.strip().lower()
    #.strip() with no arguments (or None as the first argument) removes all whitespace at the start and end, including spaces, tabs, newlines and carriage returns
    
    # replace punctuation characters with spaces
    # 
    filters='"\'#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n \r'
    translate_dict = dict((c, " ") for c in filters)
    translate_map = str.maketrans(translate_dict)
    text = text.translate(translate_map)

    return text

# %%
bhutto_text=clean_text(Bhutto1_text)

# %%
#print(bhutto_text)

# %%
# finding ! in the text directly, interjections from Bhuttto sahib book
import re
y=re.findall('[a-zA-Z]+\!+',bhutto_text)
print(y)
# Out:
# ['rigging!', 'opposition!', 'functionxexxd!', 'needle!', 'table!', 'conclusion!', 'countrymen!', 'hatred!', 'people!', 'abedi!', 'nirony!', 'nwin!']

# %%
len(y)
# Out:
# 12

# %%
#Bhutto_Speeches_1948-66

# %%
from tika import parser

raw = parser.from_file('Bhutto_Speeches_1948-66.pdf')
raw = str(raw)
Bhutto2_text = raw.encode('utf-8', errors='ignore')
Bhutto2_text = str(Bhutto2_text).replace("\n", "").replace("\\", "")
print('--- safe text ---' )
#print( Bhutto2_text )
# Out:
# 2019-04-27 08:55:23,119 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2019-04-27 08:55:28,150 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# --- safe text ---

# %%
import re
bhutto2_text=clean_text(Bhutto2_text)

# %%
y1=re.findall('[a-zA-Z]+\!+',Bhutto2_text)
print(y1)
# Out:
# ['people!', 'Japans!', 'country!', 'World!', 'God!', 'terms!']

# %%
#print(Bhutto2_text)

# %%
text1=Bhutto2_text
tokens = nltk.word_tokenize(text1)
#tokens
tagged = nltk.pos_tag(tokens)
y=list()
for word, tag in tagged:
    if tag  in ['UH']:
        y.append(word)

# %%
y
# Out:
# ['No', 'No', 'No', 'Yes', 'No', 'Well', 'No', 'Well', 'nIndia', 'xe2x80x9cOh']

# %%
text1=Bhutto1_text
tokens = nltk.word_tokenize(text1)
#tokens
tagged = nltk.pos_tag(tokens)
y=list()
for word, tag in tagged:
    if tag  in ['UH']:
        y.append(word)

# %%
y
# Out:
# ['xe2x80x9cis', 'nnYes', 'nDaoud', 'Yes', 'Oh']
